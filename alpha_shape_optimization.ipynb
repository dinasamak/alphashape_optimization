# %%
import os
import time
import math
import warnings
from typing import Iterable, Tuple, Dict, List

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from shapely.geometry import Point, MultiPoint, Polygon, MultiPolygon, LineString
from shapely.ops import unary_union, polygonize
from shapely.validation import make_valid

import geopandas as gpd
import contextily as cx
import alphashape
from scipy.spatial import Delaunay, KDTree
from tqdm import tqdm
import matplotlib.cm as cm
import matplotlib.colors as  mcolors
import folium
warnings.filterwarnings("ignore")
from IPython.display import display
import random
from utils import *
from alpha_algos import *

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# -----------------------------
# LIST OF LOCAL AUTHORITIES
# -----------------------------
local_auth = [
    "S12000005", "S12000006", "S12000008", "S12000009", "S12000010",
    "S12000011", "S12000013", "S12000014", "S12000015", "S12000017",
    "S12000018", "S12000019", "S12000020", "S12000021", "S12000023",
    "S12000024", "S12000026", "S12000027", "S12000028", "S12000029",
    "S12000030", "S12000033", "S12000034", "S12000035", "S12000036",
    "S12000038", "S12000039", "S12000040", "S12000041", "S12000042",
    "S12000043", "S12000044"
]

# %%
# -----------------------------
# FUNCTION TO LOAD DATA
# -----------------------------
def load_data(file_name="Accidents_2014.csv"):
    """
    Loads UK accident data and returns a cleaned DataFrame
    with only Longitude, Latitude, and Local Authority columns.
    Drops missing or implausible coordinates.
    """
    print("Loading data…")
    
    # Load CSV
    df = pd.read_csv(file_name)
    
    # Ensure required columns exist
    needed = ["Latitude", "Longitude", "Local_Authority_(Highway)"]
    for col in needed:
        if col not in df.columns:
            raise ValueError(f"Missing required column: {col}")
    
    # Drop rows with missing values
    df = df.dropna(subset=needed).copy()
    
    # Keep plausible UK coordinates
    df = df[
        (df["Latitude"].between(49.5, 61.5)) &
        (df["Longitude"].between(-8.5, 2.0))
    ]
    
    regions = df["Local_Authority_(Highway)"].unique()
    print(f"Regions found: {len(regions)}")
    
    # Keep only necessary columns
    df = df[["Longitude", "Latitude", "Local_Authority_(Highway)"]]
    
    return df

# %%
def map_plot(gdf):
    # Get bounding box of all geometries
    x1, y1, x2, y2 = gdf.total_bounds

    # Initialize Folium map centered on bounding box
    m = folium.Map(tiles="openstreetmap")
    m.fit_bounds([[y1, x1], [y2, x2]])

    # Assign unique colors to polygons using Matplotlib colormap
    colormap = cm.get_cmap("tab20", len(gdf))
    gdf["color"] = [mcolors.rgb2hex(colormap(i)) for i in range(len(gdf))]

    # Add polygons to Folium map with individual colors
    folium.GeoJson(
        gdf,
        style_function=lambda feature: {
            "fillColor": feature["properties"]["color"],
            "color": feature["properties"]["color"],
            "weight": 2,
            "fillOpacity": 0.6,
        },
    ).add_to(m)
    return(m)

# %%
"""
Main Workflow for Generating Alpha Shapes per Local Authority
and Visualizing Them on a Folium Map
"""


# -----------------------------
# MAIN WORKFLOW
# -----------------------------
def main():
    # Load raw data (user-defined function)
    df = load_data()

    # Store polygons generated for each local authority
    geo_arr = []

    # Process each local authority separately
    for location in local_auth:
        # Filter dataset for the current local authority
        df_cluster = df[df["Local_Authority_(Highway)"] == location]

        # Convert to list of (lon, lat) tuples
        points_list = [
            (float(lon), float(lat))
            for lon, lat in zip(df_cluster["Longitude"], df_cluster["Latitude"])
        ]

        # Determine optimal alpha parameter 
        alpha = optimized_alpha(points_list)

        # Generate polygon using alphashape 
        geom = alphashape_safe(points_list, alpha)

        # Append generated polygon to the list
        geo_arr.append(geom)

    # Create GeoDataFrame from list of polygons
    gdf = gpd.GeoDataFrame(geometry=geo_arr, crs="EPSG:4326")

    m =map_plot(gdf) 

    # Display interactive map (works in Jupyter/IPython)
    display(m)
    #-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
    #-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
    #-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
    
    #convex hull ---> alpha =0 
    
    for location in local_auth:
        # Filter dataset for the current local authority
        df_cluster = df[df["Local_Authority_(Highway)"] == location]

        # Convert to list of (lon, lat) tuples
        points_list = [
            (float(lon), float(lat))
            for lon, lat in zip(df_cluster["Longitude"], df_cluster["Latitude"])
        ]


        # Generate polygon using concave hull
        geom = alphashape_safe(points_list, 0)

        # Append generated polygon to the list
        geo_arr.append(geom)

    # Create GeoDataFrame from list of polygons
    gdf = gpd.GeoDataFrame(geometry=geo_arr, crs="EPSG:4326")
    m = map_plot(gdf)
    
    # Display interactive map (works in Jupyter/IPython)
    display(m)


# -----------------------------
# SCRIPT ENTRY POINT
# -----------------------------
if __name__ == "__main__":
    main()
# Out:
# Loading data…
# Regions found: 207
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_99a332003542981aab31b4484a3a453c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_99a332003542981aab31b4484a3a453c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_99a332003542981aab31b4484a3a453c = L.map(
#                 &quot;map_99a332003542981aab31b4484a3a453c&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7cfa9b06038e3cbe76ddbbdd793a66d9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7cfa9b06038e3cbe76ddbbdd793a66d9.addTo(map_99a332003542981aab31b4484a3a453c);
#
#
#             map_99a332003542981aab31b4484a3a453c.fitBounds(
#                 [[54.642763, -7.450342], [60.311008, -1.142155]],
#                 {}
#             );
#
#
#         function geo_json_cb59466e5f1ff4bb073e537663668597_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;:
#                     return {&quot;color&quot;: &quot;#1f77b4&quot;, &quot;fillColor&quot;: &quot;#1f77b4&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 2};
#                 case &quot;2&quot;: case &quot;3&quot;:
#                     return {&quot;color&quot;: &quot;#aec7e8&quot;, &quot;fillColor&quot;: &quot;#aec7e8&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 2};
#                 case &quot;4&quot;:
#                     return {&quot;color&quot;: &quot;#ff7f0e&quot;, &quot;fillColor&quot;: &quot;#ff7f0e&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 2};
#                 case &quot;5&quot;: case &quot;6&quot;:
#                     return {&quot;color&quot;: &quot;#ffbb78&quot;, &quot;fillColor&quot;: &quot;#ffbb78&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 2};
#                 case &quot;7&quot;:
#                     return {&quot;color&quot;: &quot;#2ca02c&quot;, &quot;fillColor&quot;: &quot;#2ca02c&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 2};
#                 case &quot;10&quot;:
#                     return {&quot;color&quot;: &quot;#d62728&quot;, &quot;fillColor&quot;: &quot;#d62728&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 2};
#                 case &quot;11&quot;: case &quot;12&quot;:
#                     return {&quot;color&quot;: &quot;#ff9896&quot;, &quot;fillColor&quot;: &quot;#ff9896&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 2};
#                 case &quot;13&quot;:
#                     return {&quot;color&quot;: &quot;#9467bd&quot;, &quot;fillColor&quot;: &quot;#9467bd&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 2};
#                 case &quot;14&quot;: case &quot;15&quot;:
#                     return {&quot;color&quot;: &quot;#c5b0d5&quot;, &quot;fillColor&quot;: &quot;#c5b0d5&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 2};
#                 case &quot;16&quot;: case &quot;17&quot;:
#                     return {&quot;color&quot;: &quot;#8c564b&quot;, &quot;fillColor&quot;: &quot;#8c564b&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 2};
#                 case &quot;18&quot;:
#                     return {&quot;color&quot;: &quot;#c49c94&quot;, &quot;fillColor&quot;: &quot;#c49c94&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 2};
#                 case &quot;19&quot;: case &quot;20&quot;:
#                     return {&quot;color&quot;: &quot;#e377c2&quot;, &quot;fillColor&quot;: &quot;#e377c2&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 2};
#                 case &quot;21&quot;:
#                     return {&quot;color&quot;: &quot;#f7b6d2&quot;, &quot;fillColor&quot;: &quot;#f7b6d2&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 2};
#                 case &quot;22&quot;: case &quot;23&quot;:
#                     return {&quot;color&quot;: &quot;#7f7f7f&quot;, &quot;fillColor&quot;: &quot;#7f7f7f&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 2};
#                 case &quot;24&quot;:
#                     return {&quot;color&quot;: &quot;#c7c7c7&quot;, &quot;fillColor&quot;: &quot;#c7c7c7&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 2};
#                 case &quot;25&quot;: case &quot;26&quot;:
#                     return {&quot;color&quot;: &quot;#bcbd22&quot;, &quot;fillColor&quot;: &quot;#bcbd22&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 2};
#                 case &quot;27&quot;:
#                     return {&quot;color&quot;: &quot;#dbdb8d&quot;, &quot;fillColor&quot;: &quot;#dbdb8d&quot;, &quot;fillOp
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cebebdec87cab72d1515edfa9f940760 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cebebdec87cab72d1515edfa9f940760&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cebebdec87cab72d1515edfa9f940760 = L.map(
#                 &quot;map_cebebdec87cab72d1515edfa9f940760&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6653cd8d9795a268d4a0cceb86b4de4a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6653cd8d9795a268d4a0cceb86b4de4a.addTo(map_cebebdec87cab72d1515edfa9f940760);
#
#
#             map_cebebdec87cab72d1515edfa9f940760.fitBounds(
#                 [[54.642763, -7.450342], [60.597984, -1.061808]],
#                 {}
#             );
#
#
#         function geo_json_87eb76410fbc03f860b80849f7b1f191_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;: case &quot;2&quot;: case &quot;3&quot;:
#                     return {&quot;color&quot;: &quot;#1f77b4&quot;, &quot;fillColor&quot;: &quot;#1f77b4&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 2};
#                 case &quot;4&quot;: case &quot;5&quot;: case &quot;6&quot;:
#                     return {&quot;color&quot;: &quot;#aec7e8&quot;, &quot;fillColor&quot;: &quot;#aec7e8&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 2};
#                 case &quot;10&quot;: case &quot;11&quot;: case &quot;12&quot;:
#                     return {&quot;color&quot;: &quot;#ffbb78&quot;, &quot;fillColor&quot;: &quot;#ffbb78&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 2};
#                 case &quot;13&quot;: case &quot;14&quot;: case &quot;15&quot;:
#                     return {&quot;color&quot;: &quot;#2ca02c&quot;, &quot;fillColor&quot;: &quot;#2ca02c&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 2};
#                 case &quot;16&quot;: case &quot;17&quot;: case &quot;18&quot;:
#                     return {&quot;color&quot;: &quot;#98df8a&quot;, &quot;fillColor&quot;: &quot;#98df8a&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 2};
#                 case &quot;19&quot;: case &quot;20&quot;: case &quot;21&quot;: case &quot;22&quot;:
#                     return {&quot;color&quot;: &quot;#d62728&quot;, &quot;fillColor&quot;: &quot;#d62728&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 2};
#                 case &quot;23&quot;: case &quot;24&quot;: case &quot;25&quot;:
#                     return {&quot;color&quot;: &quot;#ff9896&quot;, &quot;fillColor&quot;: &quot;#ff9896&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 2};
#                 case &quot;26&quot;: case &quot;27&quot;: case &quot;28&quot;:
#                     return {&quot;color&quot;: &quot;#9467bd&quot;, &quot;fillColor&quot;: &quot;#9467bd&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 2};
#                 case &quot;29&quot;: case &quot;30&quot;: case &quot;31&quot;:
#                     return {&quot;color&quot;: &quot;#c5b0d5&quot;, &quot;fillColor&quot;: &quot;#c5b0d5&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 2};
#                 case &quot;32&quot;: case &quot;33&quot;: case &quot;34&quot;:
#                     return {&quot;color&quot;: &quot;#8c564b&quot;, &quot;fillColor&quot;: &quot;#8c564b&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 2};
#                 case &quot;35&quot;: case &quot;36&quot;: case &quot;37&quot;:
#                     return {&quot;color&quot;: &quot;#c49c94&quot;, &quot;fillColor&quot;: &quot;#c49c94&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 2};
#                 case &quot;38&quot;: case &quot;39&quot;: case &quot;40&quot;:
#                     return {&quot;color&quot;: &quot;#e377c2&quot;, &quot;fillColor&quot;: &quot;#e377c2&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 2};
#                 case &quot;41&quot;: case &quot;42&quot;: case &quot;43&quot;: case &quot;44&quot;:
#                     return {&quot;color&quot;: &quot;#f7b6d2&quot;, &quot;fillColor&quot;: &quot;#f7b6d2&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 2};
#                 case &quot;45&quot;: case &quot;46&quot;: case &quot;47&quot;:
#                     return {&quot;color&quot;: &quot;#7f7f7f&quot;, &quot;fillColor&quot;: &quot;#7f7f7f&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 2};
#                 case &quot;48&quot;: case &quot;49&quot;: case &quot;50&quot;:
#                     return
